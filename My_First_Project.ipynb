# %%
import pandas as pd

# %%
df= pd.read_csv("C:/Users/pasush/PycharmProjects/First_Python_Project/sales.csv")

# %%
df.head()
# Out:
#                          Region           Country  Item Type Sales Channel  \
# 0            Sub-Saharan Africa      South Africa     Fruits       Offline
# 1  Middle East and North Africa           Morocco    Clothes        Online
# 2         Australia and Oceania  Papua New Guinea       Meat       Offline
# 3            Sub-Saharan Africa          Djibouti    Clothes       Offline
# 4                        Europe          Slovakia  Beverages       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M   7/27/2012  443368995   7/28/2012        1593        9.33
# 1              M   9/14/2013  667593514  10/19/2013        4611      109.28
# 2              M   5/15/2015  940995585    6/4/2015         360      421.89
# 3              H   5/17/2017  880811536    7/2/2017         562      109.28
# 4              L  10/26/2016  174590194   12/4/2016        3973       47.45
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
df= pd.read_csv("C:/Users/pasush/PycharmProjects/First_Python_Project/GSBRPTTB.csv")
df.head()
# Out:
#    DIS_ACTIVITY_ID  REPORT_TYPE_ID POLICY_ADMIN_COD FUNDING_COD  BILLED_DAT  \
# 0          7110464               1             ASO         REF   2016-05-31
# 1          7117491               1             ASO         REF   2016-05-31
# 2          7128637               1             ASO         REF   2016-05-31
# 3          7128647               1             ASO         REF   2016-05-31
# 4          7132906               1             ASO         REF   2016-05-31
#
#    ROLE_TID  CLAIM_TID ROLE_TYPE_DESC ROLE_TYPE_FR_DESC  GRP_POL_NUMBER  \
# 0    101650        233        RC                CR                50007
# 1    101650        233        RC                CR                50007
# 2    101650        233        RC                CR                50007
# 3    101650        233        RC                CR                50007
# 4    101650        233        RC                CR                50007
#
#                          ...                         ACTIVITY_OH_COST  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 14 columns):
# Region            1000000 non-null object
# Country           1000000 non-null object
# Item Type         1000000 non-null object
# Sales Channel     1000000 non-null object
# Order Priority    1000000 non-null object
# Order Date        1000000 non-null object
# Order ID          1000000 non-null int64
# Ship Date         1000000 non-null object
# Units Sold        1000000 non-null int64
# Unit Price        1000000 non-null float64
# Unit Cost         1000000 non-null float64
# Total Revenue     1000000 non-null float64
# Total Cost        1000000 non-null float64
# Total Profit      1000000 non-null float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 106.8+ MB

# %%
df.describe()
# Out:
#        DIS_ACTIVITY_ID  REPORT_TYPE_ID       ROLE_TID      CLAIM_TID  \
# count     1.000000e+05   100000.000000  100000.000000  100000.000000
# mean      7.879744e+06        1.652540  101650.111690     232.603260
# std       6.150647e+05        0.936664       0.314986       0.714229
# min       6.122018e+06        1.000000  101650.000000     231.000000
# 25%       7.246550e+06        1.000000  101650.000000     232.000000
# 50%       8.031992e+06        1.000000  101650.000000     233.000000
# 75%       8.546574e+06        3.000000  101650.000000     233.000000
# max       8.720276e+06        3.000000  101651.000000     233.000000
#
#        GRP_POL_NUMBER  DIVISION_NUMBER  CMPLTD_STAFF_ID   ACTIVITY_TID  \
# count   100000.000000     100000.00000    100000.000000  100000.000000
# mean    119819.459290        103.54267      5940.027880  101513.878470
# std      83963.402371        203.02941      1756.359818       2.504485
# ...

# %%
def read_auto_data(fileName = "Automobile_price_data.csv"):
    import pandas as pd 
    import numpy as np
    
    auto_prices = pd.read_csv(fileName)
    
    cols= ["price", "bore", "stroke", "horsepower", "peak-rpm"]
    for column in cols:
        auto_prices.loc[auto_prices[column] =='?', column] = np.nan
    auto_prices.dropna(axis = 0, inplace = True)
    
    for column in cols:
        auto_prices[column] = pd.to_numeric(auto_prices[column])
        
        return auto_prices
auto_prices = read_auto_data()

# %%
auto_prices.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 0  convertible          rwd           front        88.6  ...            130
# 1  convertible          rwd           front        88.6  ...            130
# 2    hatchback          rwd           front        94.5  ...            152
# 3        sedan          fwd           front        99.8  ...            109
# 4        sedan          4wd           front        99.4  ...            136
#
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
plt.plot(auto_prices["city-mpg"], auto_prices["price"], "ro")

# %%
auto_prices.plot (kind ='scatter', x = 'city-mpg', y = 'price')

# %%
auto_prices.plot (kind ='scatter', x = 'curb-weight', y = 'price')

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,6)) # define plot area 
ax = fig.gca()
auto_prices.plot (kind ='scatter', x = 'city-mpg', y = 'price', ax = ax)
ax.set_title('Scatter plot of Price vs. MPG')
ax.set_xlabel('City-MPG')
ax.set_ylabel('Auto Price')
# Out:
# Text(0, 0.5, 'Auto Price')

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(12,6)) # define plot area 
ax = fig.gca()
auto_prices.plot (kind ='scatter', x = 'curb-weight', y = 'price', ax = ax)
ax.set_title('Scatter plot of Price vs. Curb weight')
ax.set_xlabel('Curb Weight')
ax.set_ylabel('Auto Price')
# Out:
# Text(0, 0.5, 'Auto Price')

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,6)) # Define plot area
ax = fig.gca()
auto_prices.plot(kind = 'scatter', x = 'city-mpg', y = 'price', ax = ax)
ax.set_title('Scatter plot of Price vs. MPG')
ax.set_xlabel('City-MPG')
ax.set_ylabel('Auto Price')
# Out:
# Text(0, 0.5, 'Auto Price')

# %%
import pandas as pd
x = list(range(100))
y = [z*z for z in range(100)]
df = pd.DataFrame ({'x':x, 'y':y})

#now apply the previous recipe to plot x vs. y as a line chart 

fig = plt.figure(figsize=(8,6))
ax = fig.gca()
df.plot(x = 'x', y = 'y', ax = ax)
ax.set_title('Line plot of x vs. y')
ax.set_xlabel ('x')
ax.set_ylabel ('y')
# Out:
# Text(0, 0.5, 'y')

# %%
counts = auto_prices['make'].value_counts() # Find counts for each unique category
counts 

#You can see the ordered list of counts by make above. notice that this data frame has many fewer 
#row than the original, since it only needs one row for each unique value of make 

#Now create the bar plot of number of autos by make ysing the counts data frame, by executing the code in the cell below. 
#Notice, that the recipe for this chart is the same as we have used for scatter plots and line plots, just using the .plot.bar method 

fig = plt.figure(figsize=(10,10)) #define plot aread
ax = fig.gca() #define axis 
counts.plot.bar (ax =ax) # use the plot.bar method on the counts data frame 
ax.set_title ('Number of auto types by make') #Give the plot a main title 
ax.set_xlabel ('Make') # Set text for the x axis 
ax.set_ylabel ('Number of autos') # Set text for y axis 

#The bar plot clearly show which auto manufacturers have the largest number of models. 
#The more specialized makes have relatively fewer models
# Out:
# Text(0, 0.5, 'Number of autos')
